# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
hr = pd.read_csv('predict.csv')
hr = hr.sort_values(by=['chance_to_leave'], ascending=False).head(20)
hr = hr.sort_values(by=['chance_to_leave'])
hr
# Out:
#                                  name  chance_to_leave
# 20            Кирилюк Оксана Петрівна            0.089
# 46        Стрембіцька Надія Василівна            0.091
# 4            Бухта Віктор Миколайович            0.091
# 2            Бондаренко Ігор Олегович            0.101
# 21            Коваль Олена Вікторівна            0.106
# 51          Чайка Віталій Ярославович            0.108
# 0            Антипова Юлія Михайлівна            0.117
# 10                Грицун Алла Юріївна            0.118
# 23       Койчев Володимир Григорович             0.119
# 34       Островська Катерина Олегівна            0.129
# 22        Ковальчук Віктор Вікторович            0.129
# 40        Решетюк Наталія Анатоліївна            0.161
# 37        Пастух Валентина Вікторівна            0.184
# 1              Баран Роман Сергійович            0.201
# 9         Горський Нікіта Віталійович            0.203
# 17       Івасюк Владислав Віталійович            0.221
# ...

# %%
x = np.arange(len(hr['name']))
y = hr['chance_to_leave']
xlabel = hr['name']
ylabel = hr['chance_to_leave']

plt.figure(figsize=(15, 10))
plt.barh(x, y)
plt.xlabel('Employees', fontsize=10)
plt.ylabel('Chance to leave a job', fontsize=10)
plt.yticks(x, xlabel, fontsize=10, rotation=0)
plt.savefig("image/chance_to_leave.jpg")
plt.show()
